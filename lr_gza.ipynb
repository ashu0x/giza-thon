# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Load the CSV file
df = pd.read_csv('validator_data.csv')

# Function to create lag features
def create_lag_features(df, lag=1):
    for i in range(1, lag + 1):
        df[f'lag_{i}'] = df['effectiveness'].shift(i)
    return df

# Create lag features for the past 5 days
df = df.groupby('id').apply(create_lag_features, lag=7)
df = df.dropna().reset_index(drop=True)
# print(df.head())
 
# Define features and target
# features = [col for col in df.columns if 'lag_' in col]
features = ['lag_1', 'lag_2', 'lag_3', 'lag_4', 'lag_5', 'lag_6', 'lag_7', 'total_reward']
target = 'effectiveness'

# Split the data into training and testing sets
train_df = df[df['partition_date'] < '2024-05-02']
test_df = df[df['partition_date'] >= '2024-05-02']

X_train = train_df[features]
y_train = train_df[target]
X_test = test_df[features]
y_test = test_df[target]

# Initialize and train the XGBoost model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# /var/folders/pj/vyqltmgj79xghgpb38_96m040000gn/T/ipykernel_77424/3393062196.py:17: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df = df.groupby('id').apply(create_lag_features, lag=7)
# LinearRegression()

# %%
X_test.iloc[0]
# Out:
# lag_1             0.980643
# lag_2             0.979649
# lag_3             0.975971
# lag_4             0.974366
# lag_5             0.970623
# lag_6             0.965317
# lag_7             0.979038
# total_reward    875.450182
# Name: 3650, dtype: float64

# %%
from sklearn.metrics import mean_squared_error as MSE 
# Predict the model 
pred = model.predict(X_test) 

# RMSE Computation 
rmse = np.sqrt(MSE(y_test, pred)) 
print("RMSE : % f" %(rmse))
# Out:
# RMSE :  0.008284

# %%
from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType

# Define the initial types for the ONNX model
initial_type = [('float_input', FloatTensorType([None, X_train.shape[1]]))]

# Convert the scikit-learn model to ONNX
onnx_model = convert_sklearn(model, initial_types=initial_type)

# Save the ONNX model to a file
with open("linear_regression.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
# !giza transpile linear_regression.onnx --output-path verifiable_lr
# Out:
# [giza][2024-06-10 11:42:31.248] No model id provided, checking if model exists ✅
# [giza][2024-06-10 11:42:31.249] Model name is: linear_regression
# [giza][2024-06-10 11:42:32.810] Model Created with id -> 782! ✅
# [giza][2024-06-10 11:42:34.102] Version Created with id -> 1! ✅
# [giza][2024-06-10 11:42:34.103] Sending model for transpilation ✅
# [giza][2024-06-10 11:43:19.979] Transpilation is fully compatible. Version compiled and Sierra is saved at Giza ✅
# ⠏ Transpiling Model...
# [giza][2024-06-10 11:43:21.624] Downloading model ✅
# [giza][2024-06-10 11:43:21.628] model saved at: verifiable_lr

# %%
# !giza endpoints deploy --model-id 782 --version-id 1
# Out:
# ▰▰▰▰▰▱▱ Creating endpoint!t!
# [giza][2024-06-10 11:45:52.044] Endpoint is successful ✅
# [giza][2024-06-10 11:45:52.048] Endpoint created with id -> 349 ✅
# [giza][2024-06-10 11:45:52.048] Endpoint created with endpoint URL: https://endpoint-ashq-782-1-16576534-7i3yxzspbq-ew.a.run.app 🎉

# %%
from giza.agents.model import GizaModel

MODEL_ID = 782  # Update with your model ID
VERSION_ID = 1  # Update with your version ID

def prediction(input, model_id, version_id):
    model = GizaModel(id=model_id, version=version_id)

    (result, proof_id) = model.predict(
        input_feed={'input': input}, verifiable=True
    )

    return result, proof_id

def execution():
    # The input data type should match the model's expected input
    input = np.array([[0.980643, 0.979649, 0.975971, 0.974366, 0.970623, 0.965317, 0.979038, 875.450182]]).astype(np.float32)

    (result, proof_id) = prediction(input, MODEL_ID, VERSION_ID)

    print(
        f"Predicted value for input {input.flatten()[0]} is {result[0].flatten()[0]}")

    return result, proof_id


execution()
# Out:
# Payload:  Tensor<FP16x16>
# ['[1 8] [64267 0 64202 0 63961 0 63856 0 63610 0 63263 0 64162 0 57373504 0]']
# 🚀 Starting deserialization process...
# ✅ Deserialization completed! 🎉
# Predicted value for input 0.9806429743766785 is 0.97735595703125
# (array([[0.97735596]]), 'c25307bdb25941c8b6301e2f65212f9b')

# %%
# !giza endpoints get-proof --endpoint-id 349 --proof-id "c25307bdb25941c8b6301e2f65212f9b"
# Out:
# [giza][2024-06-10 11:50:18.371] Getting proof from endpoint 349 ✅
# {
#   "id": 1188,
#   "job_id": 1361,
#   "metrics": {
#     "proving_time": 13.399027
#   },
#   "created_date": "2024-06-10T06:19:41.190629"
# }

# %%
! giza endpoints download-proof --endpoint-id 349 --proof-id "c25307bdb25941c8b6301e2f65212f9b" --output-path zklr.proof
# Out:
# [giza][2024-06-10 11:51:09.895] Getting proof from endpoint 349 ✅
# [giza][2024-06-10 11:51:15.665] Proof downloaded to zklr.proof ✅

# %%
# !giza verify --proof-id 349
# Out:
# [giza][2024-06-10 11:51:16.359] Verifying proof...
# [giza][2024-06-10 11:51:18.290] Verification result: True
# [giza][2024-06-10 11:51:18.290] Verification time: 0.485350108

# %%
df.head()
# Out:
#                         id  total_validators  p_active_slots  \
# 0                  network            907305            7200
# 1             Kukis Global             10001              85
# 2  ParaFi Technologies LLC              5982              39
# 3               Blockscape              8830              89
# 4                  Figment              8928              62
#
#    p_created_blocks  non_empty_block  empty_block  vanilla_blocks  \
# 0              7141           7121.0          0.0           637.0
# 1                85             85.0          0.0             2.0
# 2                37             37.0          0.0             0.0
# 3                89             88.0          0.0             0.0
# 4                62             62.0          0.0             0.0
#
#    a_active_epochs  a_attested_epochs  a_attested_source  ...  \
# 0        203555453          202525961          202542456  ...
# 1          2250225            2250199            2249655  ...
# 2          1336358            1336313            1336041  ...
# 3          1986750            1985181            1985842  ...
# 4          2008800            2008537            2007946  ...
#
#    att_effectiveness  effectiveness  partition_date     lag_1     lag_2  \
# 0           0.958115       0.969707      2024-01-24  0.962516  0.948520
# 1           0.979543       0.987215      2024-01-24  0.982342  0.974881
# 2           0.980181       0.968382      2024-01-24  0.973834  0.974682
# 3           0.975361       0.980387      2024-01-24  0.980054  0.971271
# 4           0.976136       0.985085      2024-01-24  0.976818  0.967221
#
#       lag_3     lag_4     lag_5     lag_6     lag_7
# 0  0.946696  0.977647  0.978680  0.977154  0.971395
# 1  0.975008  0.986050  0.991527  0.989457  0.980635
# 2  0.809424  0.990879  0.985424  0.989861  0.985903
# 3  0.970209  0.984391  0.989299  0.986823  0.983941
# 4  0.972273  0.989095  0.983391  0.986877  0.958156
#
# [5 rows x 30 columns]

# %%
latest_date = df['partition_date'].max()
latest_record = df[(df['id'] == 'Figment') & (df['partition_date'] == latest_date)]
lag_features = latest_record[features].values

model = GizaModel(id=782, version=1)
input = lag_features.astype(np.float32)
(result, proof_id) = model.predict(
    input_feed={'input': input}, verifiable=True, job_size='XL'
)
result[0][0]
# Out:
# Payload:  Tensor<FP16x16>
# ['[1 8] [63400 0 63827 0 63577 0 62155 0 62148 0 62457 0 62217 0 1815227 0]']
# 🚀 Starting deserialization process...
# ✅ Deserialization completed! 🎉
# 0.9665679931640625

# %%
latest_date = df['partition_date'].max()
latest_record = df[(df['id'] == 'Figment') & (df['partition_date'] == latest_date)]
# join 2 dataframes
latest_record2 = df[(df['id'] == 'P2P.org Lido') & (df['partition_date'] == latest_date)]
latest_rec = pd.concat([latest_record, latest_record2])

lag_features = latest_rec[features].values
# latest_record = df[(df['id'] == 'P2P.org Lido') & (df['partition_date'] == latest_date)]
model = GizaModel(id=782, version=1)
input = lag_features.astype(np.float32)
(result, proof_id) = model.predict(
    input_feed={'input': input}, verifiable=True, job_size='L'
)
# result[0][0]
result, proof_id
# Out:
# Payload:  Tensor<FP16x16>
# ['[2 8] [63400 0 63827 0 63577 0 62155 0 62148 0 62457 0 62217 0 1815227 0 64596 0 64573 0 64333 0 64162 0 64468 0 64474 0 64395 0 1960349 0]']
# 🚀 Starting deserialization process...
# ✅ Deserialization completed! 🎉
# (array([[0.96656799],
#         [0.98202515]]),
#  '9dcf8e4ab36041fda333e6cd96d0eef2')

# %%
# latest date
latest_date = df['partition_date'].max()
unique_ids = df['id'].unique()
model = GizaModel(id=782, version=1)

validators = df[df['partition_date']==latest_date]

# for id in unique_ids:
    # Get the latest record for each validator
    # latest_record = df[(df['id'] == id) & (df['partition_date'] == latest_date)]
    # pd.concat([test, latest_record[features]])
    
    # Get the lag features for the latest record
    # lag_features = latest_record[features].values
    # input = lag_features.astype(np.float32)
    # Predict the effectiveness for the latest record
    # (result, proof_id) = model.predict(
    #     input_feed={'input': input}, verifiable=True, job_size='XL'
    # )
    # Update the effectiveness for the latest record
    # df.loc[(df['id'] == id) & (df['partition_date'] == latest_date), 'pred_effectiveness'] = result[0][0]
validators.head()
# Out:
#                       id  total_validators  p_active_slots  p_created_blocks  \
# 4848         Launchnodes              3062              24                24
# 4849             network            296087            2089              2088
# 4850  Staking Facilities              8400              51                51
# 4851          Blockscape              8895              58                58
# 4852      RockLogic GmbH              8892              67                67
#
#       non_empty_block  empty_block  vanilla_blocks  a_active_epochs  \
# 4848             24.0          0.0             0.0           688950
# 4849           2083.0          0.0           254.0         66553690
# 4850             50.0          0.0             0.0          1890000
# 4851             58.0          0.0             0.0          1998470
# 4852             67.0          0.0             0.0          1998080
#
#       a_attested_epochs  a_attested_source  ...  effectiveness  \
# 4848             688903             688760  ...       0.984796
# 4849           66530018           66510859  ...       0.979356
# 4850            1889188            1888308  ...       0.968891
# 4851            1998389            1998065  ...       0.987108
# 4852            1996333            1994654  ...       0.966401
#
#       partition_date     lag_1     lag_2     lag_3     lag_4     lag_5  \
# 4848      2024-06-02  0.985440  0.985436  0.982277  0.979982  0.984333
# 4849      2024-06-02  0.980668  0.981052  0.974743  0.972522  0.978541
# 4850      2024-06-02  0.977592  0.982853  0.978015  0.974768  0.984854
# 4851      2024-06-02  0.987899  0.987766  0.978826  0.981397  0.986767
# 4852      2024-06-02  0.971910  0.971303  0.959734  0.958134  0.954854
#
#          lag_6     lag_7  pred_effectiveness
# 4848  0.983956  0.985236            0.982010
# 4849  0.978494  0.978385            0.977921
# 4850  0.982768  0.981518            0.977325
# 4851  0.973869  0.987814            0.983704
# 4852  0.951840  0.941334                 NaN
#
# [5 rows x 31 columns]

# %%
lag_features = validators[features].values
input = lag_features.astype(np.float32)
model = GizaModel(id=782, version=1)
(result, proof_id) = model.predict(
        input_feed={'input': input}, verifiable=True, job_size='L'
)
print("Result: ", result, " Proof Id: ",  proof_id)
# Out:
# Payload:  Tensor<FP16x16>
# ['[39 8] [64581 0 64581 0 64374 0 64224 0 64509 0 64484 0 64568 0 623110 0 64269 0 64294 0 63880 0 63735 0 64129 0 64126 0 64119 0 60159384 0 64067 0 64412 0 64095 0 63882 0 64543 0 64406 0 64324 0 1732198 0 64742 0 64734 0 64148 0 64316 0 64668 0 63823 0 64737 0 1736128 0 63695 0 63655 0 62897 0 62792 0 62577 0 62379 0 61691 0 1840848 0 64207 0 64298 0 64377 0 63741 0 64121 0 64491 0 64450 0 4822903 0 64377 0 64253 0 64512 0 64249 0 64659 0 64627 0 64746 0 2093314 0 64596 0 64573 0 64333 0 64162 0 64468 0 64474 0 64395 0 1960349 0 64596 0 64573 0 64333 0 64162 0 64468 0 64474 0 64395 0 1960349 0 64126 0 64249 0 61282 0 63766 0 63583 0 64167 0 63267 0 1916147 0 64632 0 64559 0 64424 0 64243 0 64546 0 64503 0 64179 0 1971628 0 62973 0 63113 0 62384 0 61511 0 63005 0 62658 0 62754 0 1815926 0 64757 0 64670 0 64544 0 64325 0 64619 0 64626 0 64654 0 1878481 0 63339 0 63583 0 63465 0 63409 0 63484 0 63677 0 63366 0 1887895 0 64477 0 64411 0 64145 0 64053 0 63964 0 64304 0 64357 0 1806428 0 64763 0 64695 0 64457 0 64229 0 64588 0 64551 0 64706 0 1918226 0 64559 0 64620 0 63964 0 63413 0 64380 0 63694 0 64501 0 1843527 0 64349 0 64315 0 63990 0 63975 0 64246 0 64235 0 64340 0 1766060 0 64455 0 64707 0 64520 0 64326 0 64669 0 64637 0 64771 0 1747128 0 64684 0 64656 0 64376 0 63732 0 64344 0 64460 0 64293 0 1834591 0 63400 0 63827 0 63577 0 62155 0 62148 0 62457 0 62217 0 1815227 0 64513 0 64537 0 64273 0 64105 0 64395 0 64364 0 64425 0 1739409 0 64695 0 64681 0 64074 0 64275 0 64645 0 64631 0 64225 0 1770473 0 64667 0 64355 0 63766 0 64085 0 64363 0 64373 0 64114 0 1802750 0 64591 0 64566 0 64409 0 64159 0 64528 0 64558 0 64543 0 1557532 0 64663 0 64673 0 64469 0 64156 0 64011 0 64621 0 64677 0 1847169 0 63502 0 63364 0 63088 0 62390 0 62936 0 63268 0 63651 0 1749490 0 64627 0 64541 0 64376 0 63791 0 64522 0 64312 0 64534 0 1477508 0 63052 0 63651 0 63745 0 63691 0 64085 0 64181 0 63961 0 1771245 0 64775 0 64744 0 64152 0 64367 0 64682 0 64263 0 64788 0 1773102 0 64726 0 64701 0 64505 0 64316 0 64613 0 64619 0 64753 0 1706517 0 64363 0 64755 0 64549 0 63597 0 64665 0 64658 0 64770 0 1748632 0 64659 0 64706 0 64512 0 64302 0 64233 0 64585 0 64678 0 1842851 0 63725 0 63705 0 64290 0 64180 0 63906 0 64533 0 64603 0 1830698 0 62614 0 62225 0 62483 0 61762 0 63126 0 63144 0 63088 0 1600173 0 64459 0 64145 0 63896 0 63832 0 64444 0 63868 0 63574 0 1767445 0 64678 0 64648 0 64169 0 64179 0 64605 0 64663 0 64789 0 1691752 0 64564 0 63992 0 60495 0 64224 0 64618 0 64565 0 64782 0 1251130 0 63929 0 64647 0 63496 0 64300 0 63528 0 64594 0 63272 0 850568 0]']
# 🚀 Starting deserialization process...
# ✅ Deserialization completed! 🎉
# Result:  [[0.98200989]
#  [0.97792053]
#  [0.97732544]
#  [0.98370361]
#  [0.96929932]
#  [0.97775269]
#  [0.98013306]
#  [0.98202515]
#  [0.98202515]
#  [0.97457886]
#  [0.98249817]
#  [0.9616394 ]
#  [0.9838562 ]
#  [0.96824646]
#  [0.97998047]
#  [0.98377991]
#  [0.98078918]
#  [0.97903442]
#  [0.98161316]
#  [0.98231506]
#  [0.96656799]
#  [0.98112488]
#  [0.98312378]
#  [0.98165894]
#  [0.98204041]
#  [0.98220825]
#  [0.96725464]
#  [0.98190308]
#  [0.96723938]
#  [0.98402405]
#  [0.98362732]
#  [0.98033142]
#  [0.98266602]
#  [0.9730835 ]
#  [0.95770264]
#  [0.97967529]
#  [0.9828186 ]
#  [0.97854614]
#  [0.97555542]]  Proof Id:  1a034891afb64f9e9590a20cf20645a0

# %%
result.flatten()
# Out:
# array([0.98200989, 0.97792053, 0.97732544, 0.98370361, 0.96929932,
#        0.97775269, 0.98013306, 0.98202515, 0.98202515, 0.97457886,
#        0.98249817, 0.9616394 , 0.9838562 , 0.96824646, 0.97998047,
#        0.98377991, 0.98078918, 0.97903442, 0.98161316, 0.98231506,
#        0.96656799, 0.98112488, 0.98312378, 0.98165894, 0.98204041,
#        0.98220825, 0.96725464, 0.98190308, 0.96723938, 0.98402405,
#        0.98362732, 0.98033142, 0.98266602, 0.9730835 , 0.95770264,
#        0.97967529, 0.9828186 , 0.97854614, 0.97555542])

# %%
np.argmax(result.flatten())
# Out:
# 29

# %%
# find max id
validator = validators.iloc[np.argmax(result.flatten())]
print(f"Validator with the highest predicted effectiveness: {validator['id']} with a predicted effectiveness of {result.flatten().max()}")
# Out:
# Validator with the highest predicted effectiveness: RockawayX Infra with a predicted effectiveness of 0.9840240478515625

# %%
# !giza endpoints logs -e {349}
# Out:
# [giza][2024-06-10 13:32:44.672] Getting logs for endpoint 349 ✅
# 2024-06-10T06:15:36.219967Z  INFO orion_runner: ✅ Sierra program downloaded successfully!
# 2024-06-10T06:15:36.220032Z  INFO orion_runner: 🚀 Server running on 0.0.0.0:8080
# Default STARTUP TCP probe succeeded after 1 attempt for container "orion-runner-1" on port 8080.
# 2024-06-10T06:17:20.195965Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 5716e3512f5d46389e5ac071be9233db
# 2024-06-10T06:17:20.552201Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64052 false]"
# 2024-06-10T06:17:20.552262Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:17:21.196866Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:17:21.356247Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.bRZZHnR5oLEs/program.trace
# 2024-06-10T06:17:21.444393Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.bRZZHnR5oLEs/program.memory
# 2024-06-10T06:17:21.786080Z  INFO orion_runner: ✅ Callback sent successfully!
# The request failed because either the HTTP response was malformed or connection to the instance had an error. Additional troubleshooting documentation can be found at: https://cloud.google.com/run/docs/troubleshooting#malformed-response-or-connection-error
# thread 'tokio-runtime-worker' panicked at crates/cairo_runner/src/utils.rs:16:78:
# called `Result::unwrap()` on an `Err` value: FromStrError
# note: run with `RUST_BACKTRACE=1` environment variable to display a backtrace
# 2024-06-10T06:18:57.662681Z  INFO orion_runner: ✅ Sierra program downloaded successfully!
# 2024-06-10T06:18:57.662810Z  INFO orion_runner: 🚀 Server running on 0.0.0.0:8080
# Default STARTUP TCP probe succeeded after 1 attempt for container "orion-runner-1" on port 8080.
# 2024-06-10T06:19:12.840045Z  INFO orion_runner: 🔧 Running Sierra program with request ID: c25307bdb25941c8b6301e2f65212f9b
# 2024-06-10T06:19:13.181811Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64052 false]"
# 2024-06-10T06:19:13.181871Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:19:13.815072Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:19:13.952172Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.OGhjC9aSaqOM/program.trace
# 2024-06-10T06:19:14.017099Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.OGhjC9aSaqOM/program.memory
# 2024-06-10T06:19:14.426909Z  INFO orion_runner: ✅ Callback sent successfully!
# 2024-06-10T06:25:41.797393Z  INFO orion_runner: 🔧 Running Sierra program with request ID: bbe4ff635a774dcf9288746c79686987
# 2024-06-10T06:25:42.142259Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [63345 false]"
# 2024-06-10T06:25:42.142302Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:25:42.807103Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:25:42.990442Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.wRNCRRG2V42k/program.trace
# 2024-06-10T06:25:43.054001Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.wRNCRRG2V42k/program.memory
# 2024-06-10T06:25:43.399690Z  INFO orion_runner: ✅ Callback sent successfully!
# 2024-06-10T06:25:58.582065Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 3ad2f2ecccab442480f20d7ecd612ae9
# 2024-06-10T06:25:58.913521Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [63345 false]"
# 2024-06-10T06:25:58.913559Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:25:59.551516Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:25:59.656030Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.3Usoke2pHZyZ/program.trace
# 2024-06-10T06:25:59.712735Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.3Usoke2pHZyZ/program.memory
# 2024-06-10T06:25:59.991472Z  INFO orion_runner: ✅ Callback sent successfully!
# 2024-06-10T06:28:10.693315Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 77cf25189d1a4424a14150e69b76b5f2
# 2024-06-10T06:28:11.034596Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64089 false]"
# 2024-06-10T06:28:11.034638Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:28:11.649682Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:28:11.744168Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.2Mtu1XvMZ0jL/program.trace
# 2024-06-10T06:28:11.804751Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.2Mtu1XvMZ0jL/program.memory
# 2024-06-10T06:28:12.174542Z  INFO orion_runner: ✅ Callback sent successfully!
# 2024-06-10T06:28:12.784509Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 7a1549a49d164b5aabc068f9b0afe143
# 2024-06-10T06:28:12.941776Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64478 false]"
# 2024-06-10T06:28:12.941815Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:28:13.556452Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:28:13.691556Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.NZUSFiMdXM80/program.trace
# 2024-06-10T06:28:13.750770Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.NZUSFiMdXM80/program.memory
# 2024-06-10T06:28:14.008480Z  INFO orion_runner: ✅ Callback sent successfully!
# 2024-06-10T06:28:14.577622Z  INFO orion_runner: 🔧 Running Sierra program with request ID: d97120a8a6f7495e8ee60f830c86cad2
# 2024-06-10T06:28:14.736731Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64247 false]"
# 2024-06-10T06:28:14.736771Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:28:15.352531Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:28:15.459830Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.t92WCV5KsAAs/program.trace
# 2024-06-10T06:28:15.516788Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.t92WCV5KsAAs/program.memory
# 2024-06-10T06:28:15.803500Z  INFO orion_runner: ✅ Callback sent successfully!
# 2024-06-10T06:28:16.768493Z  INFO orion_runner: 🔧 Running Sierra program with request ID: a59ca9b4c3ef4f41aeb5289365b96cb1
# 2024-06-10T06:28:16.923469Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64468 false]"
# 2024-06-10T06:28:16.923507Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:28:17.545339Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:28:17.655672Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.ojZhdscOGnnB/program.trace
# 2024-06-10T06:28:17.724383Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.ojZhdscOGnnB/program.memory
# 2024-06-10T06:28:17.973671Z  INFO orion_runner: ✅ Callback sent successfully!
# 2024-06-10T06:28:18.566154Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 42997846031546558c0480cbe8e3e3ed
# 2024-06-10T06:28:18.718124Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [63345 false]"
# 2024-06-10T06:28:18.718166Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:28:19.347735Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:28:19.454705Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.lvt1cyJLu5ia/program.trace
# 2024-06-10T06:28:19.518993Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.lvt1cyJLu5ia/program.memory
# 2024-06-10T06:28:19.563549Z ERROR orion_runner::handlers: ⛔️ Failed to send callback: HTTP status client error (429 Too Many Requests) for url (https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349/jobs?size=M&kind=RUNNER_PROOF)
# 2024-06-10T06:28:19.563611Z ERROR orion_runner::handlers: ⛔️ Response: "{\"detail\":\"Daily job rate exceeded for size: M\"}"
# 2024-06-10T06:28:19.563647Z ERROR orion_runner::data: ⛔️ Callback failed
# 2024-06-10T06:28:19.563643Z ERROR orion_runner: ⛔️ Failed to send callback: Callback failed
# 2024-06-10T06:28:44.827885Z  INFO orion_runner: 🔧 Running Sierra program with request ID: ff623504f4e940b89cfb05067c3cd8ac
# 2024-06-10T06:28:44.992318Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [63345 false]"
# 2024-06-10T06:28:44.992358Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:28:45.598585Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:28:45.715315Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.8BYPxhdWyoFy/program.trace
# 2024-06-10T06:28:45.772850Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.8BYPxhdWyoFy/program.memory
# 2024-06-10T06:28:45.817690Z ERROR orion_runner::handlers: ⛔️ Failed to send callback: HTTP status client error (429 Too Many Requests) for url (https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349/jobs?size=M&kind=RUNNER_PROOF)
# 2024-06-10T06:28:45.817737Z ERROR orion_runner::handlers: ⛔️ Response: "{\"detail\":\"Daily job rate exceeded for size: M\"}"
# 2024-06-10T06:28:45.817780Z ERROR orion_runner::data: ⛔️ Callback failed
# 2024-06-10T06:28:45.817776Z ERROR orion_runner: ⛔️ Failed to send callback: Callback failed
# 2024-06-10T06:30:05.236128Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 6e1cbe07811248d7adc3952758f8f294
# 2024-06-10T06:30:05.391683Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [63345 false]"
# 2024-06-10T06:30:05.391720Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:30:05.998719Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:30:06.102195Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.sPrmugY59aUv/program.trace
# 2024-06-10T06:30:06.174838Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.sPrmugY59aUv/program.memory
# 2024-06-10T06:30:06.216664Z ERROR orion_runner::handlers: ⛔️ Failed to send callback: HTTP status client error (429 Too Many Requests) for url (https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349/jobs?size=M&kind=RUNNER_PROOF)
# 2024-06-10T06:30:06.216706Z ERROR orion_runner::handlers: ⛔️ Response: "{\"detail\":\"Daily job rate exceeded for size: M\"}"
# 2024-06-10T06:30:06.216740Z ERROR orion_runner::data: ⛔️ Callback failed
# 2024-06-10T06:30:06.216736Z ERROR orion_runner: ⛔️ Failed to send callback: Callback failed
# 2024-06-10T06:30:31.893569Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 261ba8bd488a4823966918cbf59dd8e5
# 2024-06-10T06:30:32.048502Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [63345 false]"
# 2024-06-10T06:30:32.048538Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:30:32.715183Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:30:32.841834Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.HmOIAS6ZTE4r/program.trace
# 2024-06-10T06:30:32.904733Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.HmOIAS6ZTE4r/program.memory
# 2024-06-10T06:30:33.171855Z  INFO orion_runner: ✅ Callback sent successfully!
# 2024-06-10T06:31:55.983844Z  INFO orion_runner: 🔧 Running Sierra program with request ID: b2005c8143394fb8975f363a0d0eaeb2
# 2024-06-10T06:31:56.138526Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64089 false]"
# 2024-06-10T06:31:56.138565Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:31:56.834606Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:31:56.957278Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.OQbDC0SgQckT/program.trace
# 2024-06-10T06:31:57.026759Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.OQbDC0SgQckT/program.memory
# 2024-06-10T06:31:57.317728Z  INFO orion_runner: ✅ Callback sent successfully!
# 2024-06-10T06:31:58.264303Z  INFO orion_runner: 🔧 Running Sierra program with request ID: c1b41af3eed04a3ca790b6a03956fbbc
# 2024-06-10T06:31:58.415634Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64478 false]"
# 2024-06-10T06:31:58.415669Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:31:59.048728Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:31:59.168151Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.GkUwQqryDQct/program.trace
# 2024-06-10T06:31:59.239643Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.GkUwQqryDQct/program.memory
# 2024-06-10T06:31:59.486436Z  INFO orion_runner: ✅ Callback sent successfully!
# 2024-06-10T06:32:00.068650Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 994f2ee242214289bb4395e8969bcf34
# 2024-06-10T06:32:00.223130Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64247 false]"
# 2024-06-10T06:32:00.223174Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:32:01.006669Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:32:01.127504Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.Uw8Lc6eW4lLO/program.trace
# 2024-06-10T06:32:01.187194Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.Uw8Lc6eW4lLO/program.memory
# 2024-06-10T06:32:01.463998Z  INFO orion_runner: ✅ Callback sent successfully!
# 2024-06-10T06:32:01.971410Z  INFO orion_runner: 🔧 Running Sierra program with request ID: feb6a8e905434e76b0308954033286eb
# 2024-06-10T06:32:02.125186Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64468 false]"
# 2024-06-10T06:32:02.125224Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:32:02.758461Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:32:02.878180Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.B5J3sizKL27Q/program.trace
# 2024-06-10T06:32:02.941931Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.B5J3sizKL27Q/program.memory
# 2024-06-10T06:32:02.982358Z ERROR orion_runner::handlers: ⛔️ Failed to send callback: HTTP status client error (429 Too Many Requests) for url (https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349/jobs?size=XL&kind=RUNNER_PROOF)
# 2024-06-10T06:32:02.982408Z ERROR orion_runner::handlers: ⛔️ Response: "{\"detail\":\"Daily job rate exceeded for size: XL\"}"
# 2024-06-10T06:32:02.982454Z ERROR orion_runner::data: ⛔️ Callback failed
# 2024-06-10T06:32:02.982448Z ERROR orion_runner: ⛔️ Failed to send callback: Callback failed
# 2024-06-10T06:55:23.753771Z  INFO orion_runner: ✅ Sierra program downloaded successfully!
# 2024-06-10T06:55:23.753843Z  INFO orion_runner: 🚀 Server running on 0.0.0.0:8080
# Default STARTUP TCP probe succeeded after 1 attempt for container "orion-runner-1" on port 8080.
# 2024-06-10T06:55:23.811286Z  INFO orion_runner: 🔧 Running Sierra program with request ID: dad8b06368884b1b8b9087acafd67894
# 2024-06-10T06:55:24.158126Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64089 false]"
# 2024-06-10T06:55:24.158184Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T06:55:24.843445Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T06:55:24.977609Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.LDhLDRjOdGn5/program.trace
# 2024-06-10T06:55:25.062863Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.LDhLDRjOdGn5/program.memory
# 2024-06-10T06:55:25.104381Z ERROR orion_runner::handlers: ⛔️ Failed to send callback: HTTP status client error (429 Too Many Requests) for url (https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349/jobs?size=XL&kind=RUNNER_PROOF)
# 2024-06-10T06:55:25.104443Z ERROR orion_runner::handlers: ⛔️ Response: "{\"detail\":\"Daily job rate exceeded for size: XL\"}"
# 2024-06-10T06:55:25.104488Z ERROR orion_runner::data: ⛔️ Callback failed
# 2024-06-10T06:55:25.104483Z ERROR orion_runner: ⛔️ Failed to send callback: Callback failed
# 2024-06-10T07:00:19.137495Z  INFO orion_runner: 🔧 Running Sierra program with request ID: b70ba64c45e3431d9790d8eda267f887
# 2024-06-10T07:00:19.290495Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64089 false]"
# 2024-06-10T07:00:19.290535Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:19.919106Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 1a03942c524241bc868817dd131b1326
# 2024-06-10T07:00:20.241786Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64478 false]"
# 2024-06-10T07:00:20.241820Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:20.937413Z  INFO orion_runner: 🔧 Running Sierra program with request ID: f3a527bc354b4d1190a98b18310f1db5
# 2024-06-10T07:00:21.098603Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64247 false]"
# 2024-06-10T07:00:21.098641Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:22.018949Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 74f75d1eec4d4ad185fbe654042f1621
# 2024-06-10T07:00:22.174459Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64468 false]"
# 2024-06-10T07:00:22.174495Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:22.771937Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 400941c5482e43adac79d0540a485121
# 2024-06-10T07:00:22.930598Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [63345 false]"
# 2024-06-10T07:00:22.930634Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:23.595669Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 213e9718159f423a806e3ac7522da639
# 2024-06-10T07:00:23.750579Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64370 false]"
# 2024-06-10T07:00:23.750623Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:24.407559Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 07f5de42128d40839194dcadc9db2930
# 2024-06-10T07:00:24.566270Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [63389 false]"
# 2024-06-10T07:00:24.566305Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:25.341240Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 316ea612214b43ec872bcece82ee1c35
# 2024-06-10T07:00:25.496183Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64400 false]"
# 2024-06-10T07:00:25.496220Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:26.139088Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 9ccab076897043258298eb0a6e4d7e2b
# 2024-06-10T07:00:26.294517Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64334 false]"
# 2024-06-10T07:00:26.294554Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:26.805740Z  INFO orion_runner: 🔧 Running Sierra program with request ID: bacc407f4ea245ce909942623c98819e
# 2024-06-10T07:00:26.962720Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64204 false]"
# 2024-06-10T07:00:26.962754Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:27.819350Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 5d8ac4d38b334870bc02baa0b9625c6f
# 2024-06-10T07:00:27.976084Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64359 false]"
# 2024-06-10T07:00:27.976121Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:28.531793Z  INFO orion_runner: 🔧 Running Sierra program with request ID: aed9c0029c794c1ca9bb159fcfa7a434
# 2024-06-10T07:00:28.688438Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64234 false]"
# 2024-06-10T07:00:28.688474Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:29.547102Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 90b3aa9deee4495ebcaf32a6898cd218
# 2024-06-10T07:00:29.710333Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [63022 false]"
# 2024-06-10T07:00:29.710369Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:30.612658Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 39a7ab1b1e0e46499ac1db070f46897d
# 2024-06-10T07:00:30.769506Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [63390 false]"
# 2024-06-10T07:00:30.769541Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:31.644832Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 179f2fbaae18474e9a36849a1e54f760
# 2024-06-10T07:00:31.799286Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64331 false]"
# 2024-06-10T07:00:31.799326Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:32.866818Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 43e977badc524f09a80336d5b11a1dbe
# 2024-06-10T07:00:33.028641Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64162 false]"
# 2024-06-10T07:00:33.028685Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:33.733046Z  INFO orion_runner: 🔧 Running Sierra program with request ID: a6c7eec810774237934e3859ee68c518
# 2024-06-10T07:00:33.888410Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [63455 false]"
# 2024-06-10T07:00:33.888446Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:34.904327Z  INFO orion_runner: 🔧 Running Sierra program with request ID: b430f1c2be014ab48bf2bacf1b2c7e6a
# 2024-06-10T07:00:35.061500Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64277 false]"
# 2024-06-10T07:00:35.061536Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:35.581444Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 9187f4df45c243a5a2f978739dcf66c0
# 2024-06-10T07:00:35.736733Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64224 false]"
# 2024-06-10T07:00:35.736771Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:36.295667Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 1469d9815e494eb99fb93d91f2248dbc
# 2024-06-10T07:00:36.451141Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64299 false]"
# 2024-06-10T07:00:36.451176Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:37.372822Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 43098400fd554fe591955d3ab272b769
# 2024-06-10T07:00:37.526315Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64377 false]"
# 2024-06-10T07:00:37.526352Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:38.142970Z  INFO orion_runner: 🔧 Running Sierra program with request ID: f9164e86c49f4ba093e35264f0c5da16
# 2024-06-10T07:00:38.300857Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64350 false]"
# 2024-06-10T07:00:38.300890Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:39.207508Z  INFO orion_runner: 🔧 Running Sierra program with request ID: e7737657323d46e8bd76867d68557664
# 2024-06-10T07:00:39.364480Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64357 false]"
# 2024-06-10T07:00:39.364515Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:39.976642Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 6da4b9c1dd57423e89ac85f19df20d83
# 2024-06-10T07:00:40.141928Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64430 false]"
# 2024-06-10T07:00:40.141964Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:40.795975Z  INFO orion_runner: 🔧 Running Sierra program with request ID: f908d528924b479ea5a00fc2399d6c5d
# 2024-06-10T07:00:40.962484Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64050 false]"
# 2024-06-10T07:00:40.962518Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:41.516548Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 76fd825147e04044956b4e0c6ad11e18
# 2024-06-10T07:00:41.678606Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64389 false]"
# 2024-06-10T07:00:41.678641Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:42.239277Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 8be46c2c34c5450fa3ba656e76d35f4c
# 2024-06-10T07:00:42.402140Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [63870 false]"
# 2024-06-10T07:00:42.402175Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:42.953724Z  INFO orion_runner: 🔧 Running Sierra program with request ID: e312b2a5c80c4efd8691ef22a1b664fd
# 2024-06-10T07:00:43.117855Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [64358 false]"
# 2024-06-10T07:00:43.117897Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# 2024-06-10T07:00:43.985197Z  INFO orion_runner: 🔧 Running Sierra program with request ID: f3d17296f51b45f18c81601c0af68051
# 2024-06-10T07:00:44.141001Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[1 1] [62764 false]"
# 2024-06-10T07:00:44.141036Z  INFO orion_runner: 🔧 Dry run request, not doing callbacks
# The request failed because either the HTTP response was malformed or connection to the instance had an error. Additional troubleshooting documentation can be found at: https://cloud.google.com/run/docs/troubleshooting#malformed-response-or-connection-error
# thread 'tokio-runtime-worker' panicked at crates/cairo_runner/src/utils.rs:16:78:
# called `Result::unwrap()` on an `Err` value: FromStrError
# note: run with `RUST_BACKTRACE=1` environment variable to display a backtrace
# 2024-06-10T07:00:45.758906Z  INFO orion_runner: ✅ Sierra program downloaded successfully!
# 2024-06-10T07:00:45.758971Z  INFO orion_runner: 🚀 Server running on 0.0.0.0:8080
# Default STARTUP TCP probe succeeded after 1 attempt for container "orion-runner-1" on port 8080.
# 2024-06-10T07:13:57.568431Z  INFO orion_runner: ✅ Sierra program downloaded successfully!
# 2024-06-10T07:13:57.568502Z  INFO orion_runner: 🚀 Server running on 0.0.0.0:8080
# Default STARTUP TCP probe succeeded after 1 attempt for container "orion-runner-1" on port 8080.
# 2024-06-10T07:13:57.629013Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 33721be5d5f045e5be5480e77f8f3f2e
# 2024-06-10T07:13:58.014864Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[2 1] [63345 false 64358 false]"
# 2024-06-10T07:13:58.014924Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T07:13:58.641158Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T07:13:58.781243Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.NCFugbLcG35L/program.trace
# 2024-06-10T07:13:58.841208Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.NCFugbLcG35L/program.memory
# 2024-06-10T07:13:58.874083Z ERROR orion_runner::handlers: ⛔️ Failed to send callback: HTTP status client error (429 Too Many Requests) for url (https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349/jobs?size=XL&kind=RUNNER_PROOF)
# 2024-06-10T07:13:58.874135Z ERROR orion_runner::handlers: ⛔️ Response: "{\"detail\":\"Daily job rate exceeded for size: XL\"}"
# 2024-06-10T07:13:58.874177Z ERROR orion_runner::data: ⛔️ Callback failed
# 2024-06-10T07:13:58.874173Z ERROR orion_runner: ⛔️ Failed to send callback: Callback failed
# 2024-06-10T07:14:09.238371Z  INFO orion_runner: 🔧 Running Sierra program with request ID: b9ce737a290842dabf6bf851aa898eb2
# 2024-06-10T07:14:09.572315Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[2 1] [63345 false 64358 false]"
# 2024-06-10T07:14:09.572360Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T07:14:10.199818Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T07:14:10.334916Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.qz5gmW71aVZn/program.trace
# 2024-06-10T07:14:10.392820Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.qz5gmW71aVZn/program.memory
# 2024-06-10T07:14:10.690406Z  INFO orion_runner: ✅ Callback sent successfully!
# 2024-06-10T07:46:44.309655Z  INFO orion_runner: ✅ Sierra program downloaded successfully!
# 2024-06-10T07:46:44.309723Z  INFO orion_runner: 🚀 Server running on 0.0.0.0:8080
# Default STARTUP TCP probe succeeded after 1 attempt for container "orion-runner-1" on port 8080.
# 2024-06-10T07:46:44.392471Z  INFO orion_runner: 🔧 Running Sierra program with request ID: ea488488155b47c9904c21d79012f8fb
# 2024-06-10T07:46:44.760918Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[39 1] [64357 false 64089 false 64050 false 64468 false 63524 false 64078 false 64234 false 64358 false 64358 false 63870 false 64389 false 63022 false 64478 false 63455 false 64224 false 64473 false 64277 false 64162 false 64331 false 64377 false 63345 false 64299 false 64430 false 64334 false 64359 false 64370 false 63390 false 64350 false 63389 false 64489 false 64463 false 64247 false 64400 false 63772 false 62764 false 64204 false 64410 false 64130 false 63934 false]"
# 2024-06-10T07:46:44.761038Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T07:46:45.477865Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T07:46:45.627038Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.lrAZqKReb2Dj/program.trace
# 2024-06-10T07:46:45.763207Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.lrAZqKReb2Dj/program.memory
# 2024-06-10T07:46:46.088681Z  INFO orion_runner: ✅ Callback sent successfully!
# 2024-06-10T07:48:25.778853Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 1a034891afb64f9e9590a20cf20645a0
# 2024-06-10T07:48:26.142197Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[39 1] [64357 false 64089 false 64050 false 64468 false 63524 false 64078 false 64234 false 64358 false 64358 false 63870 false 64389 false 63022 false 64478 false 63455 false 64224 false 64473 false 64277 false 64162 false 64331 false 64377 false 63345 false 64299 false 64430 false 64334 false 64359 false 64370 false 63390 false 64350 false 63389 false 64489 false 64463 false 64247 false 64400 false 63772 false 62764 false 64204 false 64410 false 64130 false 63934 false]"
# 2024-06-10T07:48:26.142320Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T07:48:26.783610Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T07:48:26.956015Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.aVNSB828dHEM/program.trace
# 2024-06-10T07:48:27.065632Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.aVNSB828dHEM/program.memory
# 2024-06-10T07:48:27.314131Z  INFO orion_runner: ✅ Callback sent successfully!
# 2024-06-10T08:02:09.740321Z  INFO orion_runner: ✅ Sierra program downloaded successfully!
# 2024-06-10T08:02:09.740417Z  INFO orion_runner: 🚀 Server running on 0.0.0.0:8080
# Default STARTUP TCP probe succeeded after 1 attempt for container "orion-runner-1" on port 8080.
# 2024-06-10T08:02:09.869341Z  INFO orion_runner: 🔧 Running Sierra program with request ID: 9dcf8e4ab36041fda333e6cd96d0eef2
# 2024-06-10T08:02:10.227235Z  INFO orion_runner::handlers: ✅ Cairo program ran successfully with result: "[2 1] [63345 false 64358 false]"
# 2024-06-10T08:02:10.227294Z  INFO orion_runner::handlers: 📡 Sending callback to https://model-registry-service-7i3yxzspbq-ew.a.run.app/api/v1/endpoints/349
# 2024-06-10T08:02:10.901808Z  INFO orion_runner::handlers: 📡 Request for the URLs, done
# 2024-06-10T08:02:11.051904Z  INFO orion_runner::handlers: 📡 Trace file uploaded to: /tmp/tmp.eiDox55oY17V/program.trace
# 2024-06-10T08:02:11.118157Z  INFO orion_runner::handlers: 📡 Memory file uploaded to: /tmp/tmp.eiDox55oY17V/program.memory
# 2024-06-10T08:02:11.376729Z  INFO orion_runner: ✅ Callback sent successfully!
