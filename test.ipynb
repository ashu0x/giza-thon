# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import pandas as pd
import numpy as np
import logging
from scipy.ndimage import zoom
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import mean_squared_error as mse

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
df = pd.read_csv('validator_data.csv')

# %%
df.head()
# Out:
#                         id  total_validators  p_active_slots  \
# 0              Sigma Prime             10001              83
# 1           Simply Staking              9428              88
# 2               Chorus One              8853              77
# 3         CryptoManufaktur             10001              80
# 4  Attestant (BVI) Limited             10001              69
#
#    p_created_blocks  non_empty_block  empty_block  vanilla_blocks  \
# 0                83             82.0          0.0            51.0
# 1                88             88.0          0.0             0.0
# 2                77             77.0          0.0             0.0
# 3                80             80.0          0.0             0.0
# 4                69             69.0          0.0             8.0
#
#    a_active_epochs  a_attested_epochs  a_attested_source  ...  sync_rate  \
# 0          2250225            2249558            2248718  ...  97.957517
# 1          2121300            2117898            2117410  ...  98.022129
# 2          1991925            1988552            1987913  ...  97.778459
# 3          2250225            2249817            2249157  ...  99.339419
# 4          2250225            2250199            2249164  ...  98.925253
#
#    block_reward  validation_reward  total_reward  proposal_effectiveness  \
# 0      6.568270          26.959453     33.527723                0.987952
# 1     11.981733          25.534410     37.516143                1.000000
# 2      7.538779          23.694192     31.232970                1.000000
# 3     12.021850          27.143702     39.165552                1.000000
# 4      6.736894          26.254547     32.991440                1.000000
#
#    correctness  attestation_rate  att_effectiveness  effectiveness  \
# 0     0.992777          0.999704           0.971819       0.977869
# 1     0.988021          0.998396           0.950203       0.968877
# 2     0.991658          0.998307           0.951957       0.969973
# 3     0.995019          0.999819           0.975927       0.984954
# 4     0.995301          0.999988           0.977189       0.985743
#
#    partition_date
# 0      2024-01-17
# 1      2024-01-17
# 2      2024-01-17
# 3      2024-01-17
# 4      2024-01-17
#
# [5 rows x 23 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder()
encoded_validator = encoder.fit_transform(df[['id']])
feature_names = encoder.get_feature_names_out(input_features=['id'])

encoded_validator_df = pd.DataFrame(encoded_validator, columns=feature_names)
encoded_validator_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 7
#       4 encoded_validator = encoder.fit_transform(df[['id']])
#       5 feature_names = encoder.get_feature_names_out(input_features=['id'])
# ----> 7 encoded_validator_df = pd.DataFrame(encoded_validator, columns=feature_names)
#       8 encoded_validator_df
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/pandas/core/frame.py:762, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     754         mgr = arrays_to_mgr(
#     755             arrays,
#     756             columns,
#    (...)
#     759             typ=manager,
#     760         )
#     761     else:
# --> 762         mgr = ndarray_to_mgr(
#     763             data,
#     764             index,
#     765             columns,
#     766             dtype=dtype,
#     767             copy=copy,
#     768             typ=manager,
#     769         )
#     770 else:
#     771     mgr = dict_to_mgr(
#     772         {},
#     773         index,
#    (...)
#     776         typ=manager,
#     777     )
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/pandas/core/internals/construction.py:349, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     344 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     345 index, columns = _get_axes(
#     346     values.shape[0], values.shape[1], index=index, columns=columns
#     347 )
# --> 349 _check_values_indices_shape_match(values, index, columns)
#     351 if typ == "array":
#     353     if issubclass(values.dtype.type, str):
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/site-packages/pandas/core/internals/construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (5388, 1), indices imply (5388, 42)

# %%
df['partition_date'] = pd.to_datetime(df['partition_date'])
df['year'] = df['partition_date'].dt.year
df['month'] = df['partition_date'].dt.month
df['day'] = df['partition_date'].dt.day

# %%
X = df.drop(columns=['effectiveness'])
X.head()
# Out:
#                         id  total_validators  p_active_slots  \
# 0              Sigma Prime             10001              83
# 1           Simply Staking              9428              88
# 2               Chorus One              8853              77
# 3         CryptoManufaktur             10001              80
# 4  Attestant (BVI) Limited             10001              69
#
#    p_created_blocks  non_empty_block  empty_block  vanilla_blocks  \
# 0                83             82.0          0.0            51.0
# 1                88             88.0          0.0             0.0
# 2                77             77.0          0.0             0.0
# 3                80             80.0          0.0             0.0
# 4                69             69.0          0.0             8.0
#
#    a_active_epochs  a_attested_epochs  a_attested_source  ...  inc_distance  \
# 0          2250225            2249558            2248718  ...      1.021263
# 1          2121300            2117898            2117410  ...      1.038131
# 2          1991925            1988552            1987913  ...      1.039940
# 3          2250225            2249817            2249157  ...      1.019378
# 4          2250225            2250199            2249164  ...      1.018523
#
#    sync_rate  block_reward  validation_reward  total_reward  \
# 0  97.957517      6.568270          26.959453     33.527723
# 1  98.022129     11.981733          25.534410     37.516143
# 2  97.778459      7.538779          23.694192     31.232970
# 3  99.339419     12.021850          27.143702     39.165552
# 4  98.925253      6.736894          26.254547     32.991440
#
#    proposal_effectiveness  correctness  attestation_rate  att_effectiveness  \
# 0                0.987952     0.992777          0.999704           0.971819
# 1                1.000000     0.988021          0.998396           0.950203
# 2                1.000000     0.991658          0.998307           0.951957
# 3                1.000000     0.995019          0.999819           0.975927
# 4                1.000000     0.995301          0.999988           0.977189
#
#    partition_date
# 0      2024-01-17
# 1      2024-01-17
# 2      2024-01-17
# 3      2024-01-17
# 4      2024-01-17
#
# [5 rows x 22 columns]

# %%
Y = df['effectiveness']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
def train_model(
    X_train: pd.DataFrame,
    X_test: pd.DataFrame,
    Y_train: pd.DataFrame,
    Y_test: pd.DataFrame,
):
    model = nn.Sequential(
        nn.Linear(X_train.shape[1], 128),
        nn.ReLU(),
        nn.Linear(128, 64),
        nn.ReLU(),
        nn.Linear(64, 1),
    )

    # Loss and optimizer
    criterion = nn.MSELoss()
    optimizer = optim.RMSprop(model.parameters())

    # Convert data to PyTorch tensors
    X_tensor = torch.tensor(X_train.values, dtype=torch.float32)
    y_tensor = torch.tensor(Y_train.values.reshape(-1, 1), dtype=torch.float32)
    X_test_tensor = torch.tensor(X_test.values, dtype=torch.float32)

    # Training loop
    epochs_trial = np.arange(100, 400, 4)
    batch_trial = np.arange(100, 400, 4)
    DL_pred = []
    DL_RMSE = []

    for i, j, k in zip(range(4), epochs_trial, batch_trial):
        for epoch in range(j):
            optimizer.zero_grad()
            outputs = model(X_tensor)
            loss = criterion(outputs, y_tensor)
            loss.backward()
            optimizer.step()

        with torch.no_grad():
            DL_predict = model(X_test_tensor).numpy()
            DL_RMSE.append(
                np.sqrt(mse(Y_test.values / 100, DL_predict.flatten() / 100))
            )
            DL_pred.append(DL_predict)
            print("DL_RMSE_{}:{:.6f}".format(i + 1, DL_RMSE[i]))

    return model

# %%
def main():
    model = train_model(X_train, X_test, y_train, y_test)


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 6
#       2     model = train_model(X_train, X_test, y_train, y_test)
#       5 if __name__ == "__main__":
# ----> 6     main()
#
# Cell In[64], line 2, in main()
#       1 def main():
# ----> 2     model = train_model(X_train, X_test, y_train, y_test)
#
# Cell In[52], line 20, in train_model(X_train, X_test, Y_train, Y_test)
#      17 optimizer = optim.RMSprop(model.parameters())
#      19 # Convert data to PyTorch tensors
# ---> 20 X_tensor = torch.tensor(X_train.values, dtype=torch.float32)
#      21 y_tensor = torch.tensor(Y_train.values.reshape(-1, 1), dtype=torch.float32)
#      22 X_test_tensor = torch.tensor(X_test.values, dtype=torch.float32)
#
# TypeError: can't convert np.ndarray of type numpy.object_. The only supported types are: float64, float32, float16, complex64, complex128, int64, int32, int16, int8, uint64, uint32, uint16, uint8, and bool.
